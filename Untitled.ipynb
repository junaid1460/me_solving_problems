# %%
from collections import Counter
x, y = 2,3
s = 'aaaaaaaaaaaabbbbbbb'
f = Counter(s)

def getProbDistribution(a,b):
    prob = a/b 
    print(prob, round(prob))
    r = round(prob)
    if r - prob >= 0:
        offset = -1
    else:
        offset = 1
    dist = prob / r
    counts = dist * a
    print("dist", dist)
    print("counts", counts + offset)


getProbDistribution(f['a'], f['b'])
getProbDistribution(f['b'], f['a'])
getProbDistribution(3, 3)
# Out:
# 1.7142857142857142 2
# dist 0.8571428571428571
# counts 9.285714285714285
# 0.5833333333333334 1
# dist 0.5833333333333334
# counts 3.083333333333334
# 1.0 1
# dist 1.0
# counts 2.0

# %%
w = [ 1, 1, 1, 3, 9, 11] * 100
n = len(w)
c = 4
# w = sorted(w)

def dfs(g, src, d, l, c, m):
    if d == l and c == m:
        # do something
        pass
    if d == l:
        # do somethingg
        pass
    if c == m:
        # do something
        pass
    if c > m:
        # do something
        pass
    for i in g[src+1]:

# %%
def answer(w, c, n, v):
    if c == 0:
        return v
    if n <= 0:        
        return -1
    if w[n-1]>c:
        return answer(w, c, n-1, v)
    return max(answer(w, c-w[n-1], n-1, v+1), answer(w, c, n-1, v))

print(answer(w, c, n, 0))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-4b66fae46b0f> in <module>()
#       8     return max(answer(w, c-w[n-1], n-1, v+1), answer(w, c, n-1, v))
#       9
# ---> 10 print(answer(w, c, n, 0))
#
# <ipython-input-73-4b66fae46b0f> in answer(w, c, n, v)
#       5         return -1
#       6     if w[n-1]>c:
# ----> 7         return answer(w, c, n-1, v)
#       8     return max(answer(w, c-w[n-1], n-1, v+1), answer(w, c, n-1, v))
#       9
#
# <ipython-input-73-4b66fae46b0f> in answer(w, c, n, v)
#       5         return -1
#       6     if w[n-1]>c:
# ----> 7         return answer(w, c, n-1, v)
#       8     return max(answer(w, c-w[n-1], n-1, v+1), answer(w, c, n-1, v))
#       9
#
# <ipython-input-73-4b66fae46b0f> in answer(w, c, n, v)
#       6     if w[n-1]>c:
#       7         return answer(w, c, n-1, v)
# ...
